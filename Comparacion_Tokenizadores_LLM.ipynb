# %% [markdown]
# <a href="https://colab.research.google.com/github/alegomso/plantilla-proyecto/blob/main/Comparacion_Tokenizadores_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers pandas openpyxl

# %%
from transformers import AutoTokenizer
import pandas as pd

# Frases de prueba
phrases = [
    "Transformers rock",
    "Transformers   rock",
    "#Transformers are cool!",
    "transformersrocks",
    "Trans-formers?"
]

# Modelos a comparar
models = {
    "BERT": "bert-base-uncased",
    "GPT-2": "gpt2",
    "RoBERTa": "roberta-base"
}

# Carga de tokenizadores
tokenizers = {name: AutoTokenizer.from_pretrained(path)
              for name, path in models.items()}

# %%
results = []
for phrase in phrases:
    for name, tok in tokenizers.items():
        enc = tok(phrase)
        tokens = tok.convert_ids_to_tokens(enc["input_ids"])
        results.append({
            "Frase": phrase,
            "Tokenizador": name,
            "Tokens": " ".join(tokens),
            "IDs": enc["input_ids"]
        })

# Convierte a DataFrame
df = pd.DataFrame(results)
df
# Out:
#                       Frase Tokenizador  \
# 0         Transformers rock        BERT
# 1         Transformers rock       GPT-2
# 2         Transformers rock     RoBERTa
# 3       Transformers   rock        BERT
# 4       Transformers   rock       GPT-2
# 5       Transformers   rock     RoBERTa
# 6   #Transformers are cool!        BERT
# 7   #Transformers are cool!       GPT-2
# 8   #Transformers are cool!     RoBERTa
# 9         transformersrocks        BERT
# 10        transformersrocks       GPT-2
# 11        transformersrocks     RoBERTa
# 12           Trans-formers?        BERT
# 13           Trans-formers?       GPT-2
# 14           Trans-formers?     RoBERTa
#
#                                    Tokens  \
# 0           [CLS] transformers rock [SEP]
# 1                     Transform ers Ġrock
# 2            <s> Transform ers Ġrock </s>
# 3           [CLS] transformers rock [SEP]
# 4                 Transform ers Ġ Ġ Ġrock
# 5        <s> Transform ers Ġ Ġ Ġrock </s>
# ...
